# %% [markdown]
# # nominal data

# %% [markdown]
# 1. One hot encoding
#
#    vector for each different catagory as columns
#
#    then remove any 1 column(mostly first)
#
#       for less valued data     ->thus, when we do one hot encoding, we keep n-1 columns known as dummy variables.
#
#    for data with more values->   keep most frequent columns and create catagory 'others' of remaining columns

# %%
import pandas as pd

# %%
df=pd.read_csv("cars.csv")

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df['brand'].nunique()
# Out:
# 32

# %%
cng = df[df['fuel'] == 'CNG']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 cng = df[df['fuel'] == 'CNG']
# ----> 2 cng.shape()
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# # one hot encoding using pandas

# %%
pd.get_dummies(df,columns=['fuel', 'owner'])
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000     False         True     False
# 1       Skoda     120000         370000     False         True     False
# 2       Honda     140000         158000     False        False     False
# 3     Hyundai     127000         225000     False         True     False
# 4      Maruti     120000         130000     False        False     False
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000     False        False     False
# 8124  Hyundai     119000         135000     False         True     False
# 8125   Maruti     120000         382000     False         True     False
# 8126     Tata      25000         290000     False         True     False
# 8127     Tata      25000         290000     False         True     False
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# ...

# %% [markdown]
# as we remove 1st column

# %%
pd.get_dummies(df,columns=['fuel', 'owner'],drop_first=True)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000         True     False        False
# 1       Skoda     120000         370000         True     False        False
# 2       Honda     140000         158000        False     False         True
# 3     Hyundai     127000         225000         True     False        False
# 4      Maruti     120000         130000        False     False         True
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000        False     False         True
# 8124  Hyundai     119000         135000         True     False        False
# 8125   Maruti     120000         382000         True     False        False
# 8126     Tata      25000         290000         True     False        False
# 8127     Tata      25000         290000         True     False        False
#
# ...

# %% [markdown]
# # 2. OneHotEncoding using Sklearn

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,0:4], df.iloc[:,-1],test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(drop='first', sparse_output=False, dtype = np.int32)

# %%
x_train_new=ohe.fit_transform(x_train[['fuel','owner']])
x_train_new.shape
# Out:
# (6502, 7)

# %%
x_test_new=ohe.fit_transform(x_test[['fuel','owner']])

# %%
import numpy as np

# %%
np.hstack((x_train[['brand','km_driven']].values, x_train_new))
# Out:
# array([['Hyundai', 60000, 0, ..., 0, 0, 0],
#        ['Tata', 150000, 1, ..., 0, 0, 1],
#        ['Hyundai', 110000, 1, ..., 1, 0, 0],
#        ...,
#        ['Hyundai', 90000, 0, ..., 1, 0, 0],
#        ['Volkswagen', 90000, 1, ..., 0, 0, 0],
#        ['Hyundai', 110000, 0, ..., 0, 0, 0]], dtype=object)

# %% [markdown]
# # 3. OneHotEncoding with top categories

# %%
counts = df['brand'].value_counts()

# %%
counts
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
rep1 = counts[counts <=100].index

# %%
pd.get_dummies(df['brand'].replace(rep1, 'uncommon')).sample(5)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 1736  False      False  False  False     True     False   False    False
# 2956  False      False  False  False    False     False    True    False
# 1882  False      False  False  False    False     False    True    False
# 6817  False      False  False  False    False     False   False    False
# 5615  False      False  False  False    False     False   False    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# 1736  False  False   False       False     False
# 2956  False  False   False       False     False
# 1882  False  False   False       False     False
# 6817  False   True   False       False     False
# 5615  False  False   False       False      True

# %% [markdown]
# this saperation of columns and merging is quite hectic.

# %% [markdown]
# therefore we use column transformer.
